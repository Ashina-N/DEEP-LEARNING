# %%
# import required packages
import cv2
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten
from keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Initialize image data generator with rescaling
train_data_gen = ImageDataGenerator(rescale=1./255)
validation_data_gen = ImageDataGenerator(rescale=1./255)

# %%
# Preprocess all test images
train_generator = train_data_gen.flow_from_directory(
        'C:\\Users\\s\\Desktop\\dl\\dataset\\train',
        target_size=(48, 48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 28821 images belonging to 10 classes.

# %%
# Preprocess all train images
validation_generator = validation_data_gen.flow_from_directory(
        'C:\\Users\\s\\Desktop\\dl\\dataset\\test',
        target_size=(48, 48),
        batch_size=64,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 7066 images belonging to 10 classes.

# %%
# create model structure
emotion_model = Sequential()

emotion_model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48, 48, 1)))
emotion_model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))

emotion_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
emotion_model.add(MaxPooling2D(pool_size=(2, 2)))
emotion_model.add(Dropout(0.25))

emotion_model.add(Flatten())
emotion_model.add(Dense(1024, activation='relu'))
emotion_model.add(Dropout(0.5))
emotion_model.add(Dense(10, activation='softmax'))
# Out:
# c:\Users\s\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
cv2.ocl.setUseOpenCL(False)

# %%
from tensorflow.keras.optimizers import Adam

emotion_model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.0001, decay=1e-6), metrics=['accuracy'])
# Out:
# c:\Users\s\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\optimizers\base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(

# %%
# Train the neural network/model
emotion_model_info = emotion_model.fit(
    train_generator,
    steps_per_epoch=28709 // 64,
    epochs=50,
    validation_data=validation_generator,
    validation_steps=7178 // 64
)
# Out:
# Epoch 1/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.2271 - loss: 1.8892
# c:\Users\s\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 234s 511ms/step - accuracy: 0.2271 - loss: 1.8891 - val_accuracy: 0.2784 - val_loss: 1.8056
# Epoch 2/50
# c:\Users\s\AppData\Local\Programs\Python\Python310\lib\contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 17s 37ms/step - accuracy: 0.2449 - loss: 1.7685 - val_accuracy: 0.2750 - val_loss: 1.7905
# Epoch 3/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 228s 509ms/step - accuracy: 0.3084 - loss: 1.7259 - val_accuracy: 0.4028 - val_loss: 1.5816
# Epoch 4/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.3332 - loss: 1.6661 - val_accuracy: 0.4055 - val_loss: 1.5731
# Epoch 5/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 222s 496ms/step - accuracy: 0.3900 - loss: 1.5791 - val_accuracy: 0.4292 - val_loss: 1.4894
# Epoch 6/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 17s 38ms/step - accuracy: 0.4428 - loss: 1.5630 - val_accuracy: 0.4348 - val_loss: 1.4899
# Epoch 7/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 233s 519ms/step - accuracy: 0.4264 - loss: 1.4950 - val_accuracy: 0.4592 - val_loss: 1.4196
# Epoch 8/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 17s 38ms/step - accuracy: 0.4269 - loss: 1.4159 - val_accuracy: 0.4532 - val_loss: 1.4235
# Epoch 9/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 229s 510ms/step - accuracy: 0.4460 - loss: 1.4304 - val_accuracy: 0.4810 - val_loss: 1.3696
# Epoch 10/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 17s 37ms/step - accuracy: 0.4376 - loss: 1.4482 - val_accuracy: 0.4724 - val_loss: 1.3725
# Epoch 11/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 228s 508ms/step - accuracy: 0.4740 - loss: 1.3783 - val_accuracy: 0.4929 - val_loss: 1.3298
# Epoch 12/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 18s 39ms/step - accuracy: 0.4897 - loss: 1.3608 - val_accuracy: 0.4926 - val_loss: 1.3265
# Epoch 13/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 235s 525ms/step - accuracy: 0.4994 - loss: 1.3200 - val_accuracy: 0.5059 - val_loss: 1.2917
# Epoch 14/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 18s 39ms/step - accuracy: 0.3905 - loss: 1.5116 - val_accuracy: 0.5119 - val_loss: 1.2813
# Epoch 15/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 249s 555ms/step - accuracy: 0.5149 - loss: 1.2869 - val_accuracy: 0.5301 - val_loss: 1.2487
# Epoch 16/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 20s 43ms/step - accuracy: 0.4893 - loss: 1.2820 - val_accuracy: 0.5273 - val_loss: 1.2493
# Epoch 17/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 228s 508ms/step - accuracy: 0.5326 - loss: 1.2355 - val_accuracy: 0.5481 - val_loss: 1.2146
# Epoch 18/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 17s 38ms/step - accuracy: 0.5258 - loss: 1.2247 - val_accuracy: 0.5430 - val_loss: 1.2201
# Epoch 19/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 233s 519ms/step - accuracy: 0.5496 - loss: 1.2069 - val_accuracy: 0.5522 - val_loss: 1.2013
# Epoch 20/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 17s 38ms/step - accuracy: 0.5471 - loss: 1.1831 - val_accuracy: 0.5584 - val_loss: 1.1928
# Epoch 21/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 363s 811ms/step - accuracy: 0.5559 - loss: 1.1885 - val_accuracy: 0.5599 - val_loss: 1.1777
# Epoch 22/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 21s 45ms/step - accuracy: 0.5779 - loss: 1.1079 - val_accuracy: 0.5665 - val_loss: 1.1681
# Epoch 23/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 265s 592ms/step - accuracy: 0.5736 - loss: 1.1413 - val_accuracy: 0.5712 - val_loss: 1.1689
# Epoch 24/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 20s 43ms/step - accuracy: 0.5988 - loss: 1.1245 - val_accuracy: 0.5696 - val_loss: 1.1770
# Epoch 25/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 242s 540ms/step - accuracy: 0.5822 - loss: 1.1207 - val_accuracy: 0.5736 - val_loss: 1.1413
# Epoch 26/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 17s 38ms/step - accuracy: 0.6145 - loss: 0.9849 - val_accuracy: 0.5759 - val_loss: 1.1430
# Epoch 27/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 239s 532ms/step - accuracy: 0.5938 - loss: 1.0978 - val_accuracy: 0.5771 - val_loss: 1.1318
# Epoch 28/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 17s 38ms/step - accuracy: 0.5573 - loss: 1.1050 - val_accuracy: 0.5810 - val_loss: 1.1290
# Epoch 29/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 292s 652ms/step - accuracy: 0.5983 - loss: 1.0726 - val_accuracy: 0.5808 - val_loss: 1.1360
# Epoch 30/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 19s 40ms/step - accuracy: 0.6251 - loss: 1.1000 - val_accuracy: 0.5801 - val_loss: 1.1373
# Epoch 31/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 236s 527ms/step - accuracy: 0.6237 - loss: 1.0249 - val_accuracy: 0.5848 - val_loss: 1.1100
# Epoch 32/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 23s 49ms/step - accuracy: 0.6615 - loss: 0.9491 - val_accuracy: 0.5860 - val_loss: 1.1068
# Epoch 33/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 296s 659ms/step - accuracy: 0.6306 - loss: 1.0017 - val_accuracy: 0.5940 - val_loss: 1.0972
# Epoch 34/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.6772 - loss: 0.8941 - val_accuracy: 0.5940 - val_loss: 1.0974
# Epoch 35/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 224s 499ms/step - accuracy: 0.6292 - loss: 0.9961 - val_accuracy: 0.5992 - val_loss: 1.0869
# Epoch 36/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 17s 37ms/step - accuracy: 0.6458 - loss: 0.9239 - val_accuracy: 0.5995 - val_loss: 1.0879
# Epoch 37/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 232s 518ms/step - accuracy: 0.6473 - loss: 0.9566 - val_accuracy: 0.6030 - val_loss: 1.0784
# Epoch 38/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 17s 38ms/step - accuracy: 0.6718 - loss: 0.8819 - val_accuracy: 0.6035 - val_loss: 1.0776
# Epoch 39/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 230s 512ms/step - accuracy: 0.6506 - loss: 0.9515 - val_accuracy: 0.6006 - val_loss: 1.0810
# Epoch 40/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.6561 - loss: 0.9010 - val_accuracy: 0.5989 - val_loss: 1.0834
# Epoch 41/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 227s 507ms/step - accuracy: 0.6631 - loss: 0.9265 - val_accuracy: 0.6067 - val_loss: 1.0750
# Epoch 42/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 17s 37ms/step - accuracy: 0.5989 - loss: 1.0481 - val_accuracy: 0.6073 - val_loss: 1.0728
# Epoch 43/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 231s 516ms/step - accuracy: 0.6736 - loss: 0.8904 - val_accuracy: 0.6042 - val_loss: 1.0779
# Epoch 44/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 17s 37ms/step - accuracy: 0.6457 - loss: 0.9577 - val_accuracy: 0.6084 - val_loss: 1.0657
# Epoch 45/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 233s 520ms/step - accuracy: 0.6766 - loss: 0.8747 - val_accuracy: 0.6100 - val_loss: 1.0665
# Epoch 46/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 17s 37ms/step - accuracy: 0.7188 - loss: 0.9082 - val_accuracy: 0.6117 - val_loss: 1.0652
# Epoch 47/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 230s 513ms/step - accuracy: 0.6793 - loss: 0.8592 - val_accuracy: 0.6134 - val_loss: 1.0620
# Epoch 48/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 17s 38ms/step - accuracy: 0.6978 - loss: 0.7563 - val_accuracy: 0.6122 - val_loss: 1.0596
# Epoch 49/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 233s 520ms/step - accuracy: 0.6986 - loss: 0.8247 - val_accuracy: 0.6118 - val_loss: 1.0616
# Epoch 50/50
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 18s 39ms/step - accuracy: 0.6821 - loss: 0.8930 - val_accuracy: 0.6091 - val_loss: 1.0611

# %%
# save model structure in jason file
model_json = emotion_model.to_json()
with open("emotion_model.json", "w") as json_file:
    json_file.write(model_json)

# %%
# save trained model weight in .h5 file
emotion_model.save('emotion_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import cv2
haar_file=cv2.data.haarcascades + 'C:\\Users\\s\\Desktop\\dl\\haarcascade_frontalface_default.xml'
face_cascade=cv2.CascadeClassifier(haar_file)

# %%
# Start capturing video
import cv2
from deepface import DeepFace

# Load face cascade classifier
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'C:\\Users\\s\\Desktop\\dl\\haarcascade_frontalface_default.xml')

# Start capturing video
cap = cv2.VideoCapture(0)

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()

    # Convert frame to grayscale
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Convert grayscale frame to RGB format
    rgb_frame = cv2.cvtColor(gray_frame, cv2.COLOR_GRAY2RGB)

    # Detect faces in the frame
    faces = face_cascade.detectMultiScale(gray_frame, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    for (x, y, w, h) in faces:
        # Extract the face ROI (Region of Interest)
        face_roi = rgb_frame[y:y + h, x:x + w]
        # Perform emotion analysis on the face ROI
        result = DeepFace.analyze(face_roi, actions=['emotion'], enforce_detection=False)
        # Determine the dominant emotion
        emotion = result[0]['dominant_emotion']

        # Draw rectangle around face and label with predicted emotion
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 0, 255), 2)
        cv2.putText(frame, emotion, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 255), 2)

    # Display the resulting frame
    cv2.imshow('Real-time Emotion Detection', frame)

    # Press 'q' to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the capture and close all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:tensorflow:From c:\Users\s\AppData\Local\Programs\Python\Python310\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
